# %%
import pandas as pd
from sklearn import linear_model

# %%
df = pd.read_csv("hiring.csv")
df.columns = df.columns.str.strip()

word_to_num = {
    "zero": 0,
    "one": 1,
    "two": 2,
    "three": 3,
    "four": 4,
    "five": 5,
    "six": 6,
    "seven": 7,
    "eight": 8,
    "nine": 9,
    "ten": 10,
    "eleven": 11,
    "twelve": 12,
}

# %%
experience = df["experience"].astype(str).str.strip().str.lower()
df["experience"] = experience.map(word_to_num)
df["experience"] = df["experience"].fillna(pd.to_numeric(experience, errors="coerce"))

df["test_score"] = pd.to_numeric(df["test_score"], errors="coerce")
df["interview_score"] = pd.to_numeric(df["interview_score"], errors="coerce")

df["experience"] = df["experience"].fillna(df["experience"].median())
df["test_score"] = df["test_score"].fillna(df["test_score"].median())
df["interview_score"] = df["interview_score"].fillna(df["interview_score"].median())

df
# Out:
#    experience  test_score  interview_score  salary
# 0         6.0         8.0                9   50000
# 1         6.0         8.0                6   45000
# 2         5.0         6.0                7   60000
# 3         2.0        10.0               10   65000
# 4         7.0         9.0                6   70000
# 5         3.0         7.0               10   62000
# 6        10.0         8.0                7   72000
# 7        11.0         7.0                8   80000

# %%
reg = linear_model.LinearRegression()

# %%
reg.fit(df[['experience', 'test_score', 'interview_score']], df['salary'])
# Out:
# LinearRegression()

# %%
prediction1 = reg.predict(
    pd.DataFrame(
        [[2,9,6]],
        columns=['experience','test_score','interview_score']
    )
)

print(prediction1)
# Out:
# [47056.91056911]

# %%
prediction2 = reg.predict(
    pd.DataFrame(
        [[12,10,10]],
        columns=['experience','test_score','interview_score']
    )
)

print(prediction2)
# Out:
# [88227.64227642]

# %%
reg.coef_
# Out:
# array([2813.00813008, 1333.33333333, 2926.82926829])

# %%
reg.intercept_
# Out:
# np.float64(11869.91869918695)
