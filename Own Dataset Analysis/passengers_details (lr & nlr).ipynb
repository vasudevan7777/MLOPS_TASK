# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

df = pd.read_csv("D:\SMART COACH\data\passenger_detail.csv")

plt.scatter(df['age'], df['fare'])
plt.xlabel("Age")
plt.ylabel("Fare")

model = LinearRegression()
model.fit(df[['age']], df['fare'])
model.predict(
    pd.DataFrame([[25]], columns=['age'])
)
print("Predicted Fare:", prediction)
# Out:
# Predicted Fare: [1343.28891481]

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

df = pd.read_csv("D:\SMART COACH\data\passenger_detail.csv")

plt.scatter(df['age'], df['fare'])
plt.xlabel("Age")
plt.ylabel("Fare")

poly = PolynomialFeatures(degree=2)
X_poly = poly.fit_transform(df[['age']])
model = LinearRegression()
model.fit(X_poly, df['fare'])

poly.transform(
    pd.DataFrame([[25]], columns=['age'])
)
print("Predicted Fare:", prediction)
# Out:
# Predicted Fare: [1343.28891481]
